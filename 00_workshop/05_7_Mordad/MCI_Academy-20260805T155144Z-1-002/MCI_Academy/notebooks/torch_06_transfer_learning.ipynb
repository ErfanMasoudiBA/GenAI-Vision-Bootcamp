# %% [markdown]
# <div dir="rtl">
#   <p style="color: #80f9fa; text-align: right;">
#     <b>یادگیری انتقالی</b>
#   </p>
# </div>

# %% [markdown]
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torchvision.models as models

# model = Model()
model = models.resnet18(weights=None)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torchvision.models as models

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 177MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
import torchvision.models as models
from torchvision.models import ResNet18_Weights

resnet18 = models.resnet18(weights=None)
# resnet18 = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)

print(resnet18)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 210MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
# ...

# %%
import torchvision.models as models
model1 = models.resnet18(weights=None)
model2 = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
import torch
torch.equal(model1.conv1.weight, model2.conv1.weight)
# Out:
# False

# %%
import torch

resnet18 = models.resnet18(weights=None)
checkpoint_path = '/content/drive/MyDrive/MCI_Academy/checkpoints/resnet18-f37072fd.pth'
resnet18.load_state_dict(torch.load(checkpoint_path))

# print(resnet18)
# Out:
# <All keys matched successfully>

# %%
resnet18.load_state_dict(torch.load(checkpoint_path))
# Out:
# <All keys matched successfully>

# %%
import torch

resnet18 = models.resnet18(weights=None)
checkpoint_path = '../checkpoints/resnet18-f37072fd.pth'
resnet18.load_state_dict(torch.load(checkpoint_path))

print(resnet18)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
for name, param in model.named_parameters():
    # print(name, param.size())

    param.requires_grad = False
    print(param.requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
resnet18 = models.resnet18(weights=None)
checkpoint_path = '../checkpoints/resnet18-f37072fd.pth'
resnet18.load_state_dict(torch.load(checkpoint_path))

for name, param in resnet18.named_parameters():
    print(name, param.size())
    param.requires_grad = False
# Out:
# conv1.weight torch.Size([64, 3, 7, 7])
# bn1.weight torch.Size([64])
# bn1.bias torch.Size([64])
# layer1.0.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn1.weight torch.Size([64])
# layer1.0.bn1.bias torch.Size([64])
# layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn2.weight torch.Size([64])
# layer1.0.bn2.bias torch.Size([64])
# layer1.1.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn1.weight torch.Size([64])
# layer1.1.bn1.bias torch.Size([64])
# layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn2.weight torch.Size([64])
# layer1.1.bn2.bias torch.Size([64])
# layer2.0.conv1.weight torch.Size([128, 64, 3, 3])
# layer2.0.bn1.weight torch.Size([128])
# layer2.0.bn1.bias torch.Size([128])
# layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# layer2.0.bn2.weight torch.Size([128])
# layer2.0.bn2.bias torch.Size([128])
# layer2.0.downsample.0.weight torch.Size([128, 64, 1, 1])
# layer2.0.downsample.1.weight torch.Size([128])
# ...

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
for name, param in model.named_parameters():
    param.requires_grad = False
    if 'fc' in name:
      param.requires_grad = True
    print(param.requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.train()
for name, param in model.named_parameters():
    param.requires_grad = False
    if 'fc' in name:
      param.requires_grad = True
    print(param.requires_grad)

# %%
resnet18 = models.resnet18(weights=None)
checkpoint_path = '../checkpoints/resnet18-f37072fd.pth'
resnet18.load_state_dict(torch.load(checkpoint_path))

resnet18.train()
for name, param in resnet18.named_parameters():
    print(name, param.size())
    if 'fc' in name:
        param.requires_grad = True
# Out:
# conv1.weight torch.Size([64, 3, 7, 7])
# bn1.weight torch.Size([64])
# bn1.bias torch.Size([64])
# layer1.0.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn1.weight torch.Size([64])
# layer1.0.bn1.bias torch.Size([64])
# layer1.0.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.0.bn2.weight torch.Size([64])
# layer1.0.bn2.bias torch.Size([64])
# layer1.1.conv1.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn1.weight torch.Size([64])
# layer1.1.bn1.bias torch.Size([64])
# layer1.1.conv2.weight torch.Size([64, 64, 3, 3])
# layer1.1.bn2.weight torch.Size([64])
# layer1.1.bn2.bias torch.Size([64])
# layer2.0.conv1.weight torch.Size([128, 64, 3, 3])
# layer2.0.bn1.weight torch.Size([128])
# layer2.0.bn1.bias torch.Size([128])
# layer2.0.conv2.weight torch.Size([128, 128, 3, 3])
# layer2.0.bn2.weight torch.Size([128])
# layer2.0.bn2.bias torch.Size([128])
# layer2.0.downsample.0.weight torch.Size([128, 64, 1, 1])
# layer2.0.downsample.1.weight torch.Size([128])
# ...

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
for name, param in model.named_parameters():
    if 'fc' in name:
      print(name, param.shape)
# Out:
# fc.weight torch.Size([1000, 512])
# fc.bias torch.Size([1000])

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = torch.nn.Linear(512, 10)
for name, param in model.named_parameters():
    param.requires_grad = False
    if 'fc' in name:
      print(name, param.shape)
      param.requires_grad = True
# Out:
# fc.weight torch.Size([10, 512])
# fc.bias torch.Size([10])

# %%
resnet18 = models.resnet18(weights=None)
checkpoint_path = '../checkpoints/resnet18-f37072fd.pth'
resnet18.load_state_dict(torch.load(checkpoint_path))

resnet18.fc = torch.nn.Linear(512, 10)
for name, param in resnet18.named_parameters():
    if not 'fc' in name:
        param.requires_grad = False

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# تمرین:
# با استفاده از معماری
# resnet
# و بارگیری وزن‌های مربوطه، آموزش طبقه‌بند سیفار۱۰ را به ترتیب با بخش‌های زیر انجام دهید:
# ۱- تهیه دیتاست و دیتالودر
# ۲- تعریف چرخه مناسب آموزش و ارزیابی
# ۳- رسم ماتریس کانفیوژن
# ۴- محاسبه دقت
# ۵- ذخیره مدل
# </div>

# %%
model = Model()
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = torch.nn.Linear(512, 10)
