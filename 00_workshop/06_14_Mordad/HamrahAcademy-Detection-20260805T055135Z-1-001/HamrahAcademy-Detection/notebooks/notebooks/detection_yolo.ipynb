# %% [markdown]
# <div dir="rtl">
#   <h1 style="color: #80f9fa; text-align: right;">
#     <b>آموزش مدل دتکشن بر اساس پکیج آلترالیتیکس</b>
#   </h1>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#       <h2 style="text-align: right;">
# نصب پکیج:
#   </h2>
# </div>

# %%
! pip install ultralytics
! pip install ultralytics==8.4.115
# Out:
# Requirement already satisfied: ultralytics in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (8.4.115)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.16.1)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.13.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.28.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.43.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from polars>=0.20.0->ultralytics) (1.43.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# DEPRECATION: Loading egg at c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages\prime_sieve-0.1.11-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ultralytics==8.4.115 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (8.4.115)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (3.16.1)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (2.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (3.10.8)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (2.32.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (2.13.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (0.28.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from ultralytics==8.4.115) (6.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (1.43.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from ultralytics==8.4.115) (2.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (24.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics==8.4.115) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from polars>=0.20.0->ultralytics==8.4.115) (1.43.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.4.115) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.4.115) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.4.115) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.4.115) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (4.12.2)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.4.115) (2024.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\erfan\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.4.115) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.4.115) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.4.115) (3.0.2)
# DEPRECATION: Loading egg at c:\users\erfan\appdata\local\programs\python\python312\lib\site-packages\prime_sieve-0.1.11-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Pip install method (recommended)

#!pip install ultralytics
#!pip install ultralytics==8.4.115

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 396.4/465.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#     <h2 style="text-align: right;">
# نحوه اجرا بوسیله CLI:
# </h2>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# اگر میخواهید از یولو استفاده کنید و هیچ نیازی به تغییر کد ندارید میتوانید از رابط خط فرمان استفاده کنید.
#   برای اطلاعات بیشتر لینک  <a href="https://docs.ultralytics.com/usage/cli/"> مستندات آلترالیتیکس مربوط به رابط خط فرمان </a> را نگاه کنید.
# </div>
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://jacksons.law/wp-content/uploads/2024/11/Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png' save=True
# Out:
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://jacksons.law/wp-content/uploads/2024/11/Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png locally at Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png
# image 1/1 d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png: 384x640 2 dogs, 1 horse, 54.7ms
# Speed: 1.7ms preprocess, 54.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\predict-2
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/detect/predict/Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.jpg', width=600)

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#     <h2 style="text-align: right;">
# نحوه اجرای استنتاج در پایتون
#     </h2>
# </div>

# %%
model = YOLO('yolov8n.pt')
image_path = 'Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png'
results = model.predict(image_path, conf=0.25)
# Out:
# image 1/1 d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\Equine-Blog-A-dog-spooked-my-horse-Feature-image-900x507.png: 384x640 2 dogs, 1 horse, 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2 
import matplotlib.pyplot as plt

print(results[0].boxes.xyxy)
print(results[0].boxes.conf)
print(results[0].boxes.cls)

img = cv2.imread(image_path)
for r in results:
    for i, box in enumerate(r.boxes.xyxy):
        x1, y1, x2, y2 = map(int, box) # Convert coordinates to integers
        label = f'{r.names[int(r.boxes.cls[i])]} {r.boxes.conf[i]:.2f}'

        # Draw bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2) # Green box, thickness 2

        # Add label and confidence score
        cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

# Convert BGR image to RGB for Matplotlib display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image with Matplotlib
plt.imshow(img_rgb)
plt.axis('off') # Hide axes
plt.show()
# Out:
# tensor([[325.0417,  63.6572, 859.8954, 466.4848],
#         [164.2445, 301.8849, 329.0693, 422.6165],
#         [101.8577, 310.6982, 192.3206, 429.4275]])
# tensor([0.9298, 0.7508, 0.6640])
# tensor([17., 16., 16.])

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h1 style="text-align: right;">
# پایگاه داده برای آموزش مدل:
#  </h1>
# بسیاری از پایگاه دادگان در اینترنت وجود دارد که میتوانید از آن استفاده کنید. بعنوان مثال
#     RoboFlow حاوی ده‌ها هزار داده است که میتوان از آن استفاده کرد
# </div>

# %% [markdown]
# <a href="https://universe.roboflow.com" target="_blank" style="display: block; text-align: center;">
#     <img src="../pictures/roboflow.jpg" alt="سایت" width="700">
# </a>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h2 style="text-align: right;">
#  استفاده از پایگاه داده </h2>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قبل از شروع نیاز است
# <a href="https://app.roboflow.com/login">
#   یک اکانت
# </a>
# بسازید.
# بعد از ورود به اکانت در قسمت اکسپلور پایگاه داده را انتخاب کرده و آن را اضافه میکنید
# </div>
# <div>
# <img src="../pictures/fork1.png" alt="مرحله ۱" width="700">
# <img src="../pictures/fork2.png" alt="مرحله ۲" width="700">
# <img src="../pictures/fork3.png" alt="مرحله ۳" width="700">
# <img src="../pictures/fork4.png" alt="مرحله ۴" width="700">
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# استفاده کردن از کد و کمی تغییر آن که توکن را بگیرد.
# </div>
# <div>
# <img src="../pictures/fork5.png" alt="مرحله ۵" width="700">
# <img src="../pictures/fork6.png" alt="مرحله ۶" width="700">
# </div>

# %%
#!pip install roboflow
if False:
    import roboflow
    from roboflow import Roboflow
    
    roboflow.login(force=True)
    rf = Roboflow()
    project = rf.workspace("reshad").project("tyre-gpufb-ujyoq")
    version = project.version(2)
    dataset = version.download("yolov8", overwrite=False)
    
    data_location = dataset.location
    print(data_location)
else:
    data_location = '../notebooks-data/tyre-2'

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# محتویات پوشه دانلود شده و فایل اطلاعات داده
# فایل متنی پنج عدد که به ترتیب کلاس شیء، فاصلی افقی و عمودی مرکز و عرض و ارتفاع نرمالیزه شده است.
# <img src="../pictures/data1.png" alt="محتویات پوشه" width="400">
# <img src="../pictures/data2.png" alt="محتویات فایل" width="400">
# <img src="../pictures/data3.png" width="400">
# <img src="../pictures/data4.png" width="400">
# <img src="../pictures/data5.png" width="400">
# <img src="../pictures/data6.png" width="400">
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h1 style="text-align: right;">
# آموزش مدل:
#  </h1>
# با مشخص کردن هایپرپارامترها و فراخوانی مدل، مدل آموزش میبیند
# </div>

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={data_location}/data.yaml epochs=1 imgsz=640 plots=True project='yolov8' name='experiment_cmd'
# Out:
# New https://pypi.org/project/ultralytics/8.4.120 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../notebooks-data/tyre-2/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=1, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment_cmd-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolov8, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment_cmd-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Traceback (most recent call last):
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 792, in get_dataset
#     data = check_det_dataset(self.args.data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\data\utils.py", line 493, in check_det_dataset
#     file = Path(check_file(dataset))
#                 ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\utils\checks.py", line 720, in check_file
#     raise FileNotFoundError(f"'{file}' does not exist")
# FileNotFoundError: '../notebooks-data/tyre-2/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\cfg\__init__.py", line 1123, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py", line 816, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\models\yolo\detect\train.py", line 62, in __init__
#     super().__init__(cfg, overrides, _callbacks)
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 185, in __init__
#     self.data = self.get_dataset()
#                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Erfan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py", line 796, in get_dataset
#     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
# RuntimeError: Dataset '../notebooks-data/tyre-2/data.yaml' error  '../notebooks-data/tyre-2/data.yaml' does not exist

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h2 style="text-align: right;">
# آموزش مدل در محیط پایتون:
#  </h2>
# مشخص کردن نام پروژه و نام آزمایش برای محل ذخیره کردن نتایج
# </div>

# %%
model = YOLO("yolov8n.pt")  # pass any model type
results = model.train(epochs=5, data= f'../../notebooks-data/tyre-2/data.yaml', project='yolov8', name='experiment')
# Out:
# New https://pypi.org/project/ultralytics/8.4.120 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../../notebooks-data/tyre-2/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=experiment-6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=yolov8, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\Erfan\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 2.1MB/s 0.4s 0.3s<0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# WARNING train: Slow image access detected (ping: 0.20.0 ms, read: 38.323.1 MB/s, size: 326.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\train\labels... 276 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 276/276 370.5it/s 0.7s0.0s
# train: New cache created: D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\train\labels.cache
# WARNING val: Slow image access detected (ping: 0.20.1 ms, read: 48.611.5 MB/s, size: 438.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\valid\labels... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78 352.3it/s 0.2s0.1s
# val: New cache created: D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\valid\labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      1.262      2.442      1.164         18        640: 100% ━━━━━━━━━━━━ 18/18 8.7s/it 2:364.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8s/it 14.4s<10.3s
#                    all         78        183    0.00765      0.978      0.383      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      1.203      1.365      1.061         16        640: 100% ━━━━━━━━━━━━ 18/18 7.6s/it 2:174.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8s/it 14.3s<10.3s
#                    all         78        183    0.00667      0.852     0.0349     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      1.146      1.183      1.051         14        640: 100% ━━━━━━━━━━━━ 18/18 8.1s/it 2:254.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s<10.8s
#                    all         78        183          1      0.158      0.607      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      1.088      1.042       1.01         16        640: 100% ━━━━━━━━━━━━ 18/18 7.7s/it 2:183.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.1s/it 15.2s<10.8s
#                    all         78        183       0.99      0.564      0.844      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G      1.005      0.917     0.9862         21        640: 100% ━━━━━━━━━━━━ 18/18 7.8s/it 2:204.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0s/it 14.9s<10.7s
#                    all         78        183       0.94      0.907      0.966      0.718
#
# 5 epochs completed in 0.220 hours.
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6\weights\last.pt, 6.2MB
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6\weights\best.pt, 6.2MB
#
# Validating D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6\weights\best.pt...
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.6s/it 13.8s.8s2s
#                    all         78        183      0.941      0.907      0.966      0.718
# Speed: 3.0ms preprocess, 106.3ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\experiment-6

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# مشاهده بعضی از نتایج.
# </div>

# %%
display(Image(filename=f'./runs/detect/yolov8/experiment-6/results.png', width=600))
display(Image(filename=f'./runs/detect/yolov8/experiment-6/BoxPR_curve.png', width=600))

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# اگر به هر دلیلی آموزش متوقف شده بود میتوان آموزش را دوباره ادامه داد.
# </div>

# %%
# model = YOLO("yolov8/experiment/last.pt")
# results = model.train(resume=True)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# آموزش مدل از صفر بر روی پایگاه داده بزرگ
# </div>

# %%
# from ultralytics import YOLO

# model = YOLO("yolo11n.yaml")
# results = model.train(data="coco8.yaml", epochs=300)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# در قسمتی که پکیج نصب شده کانفیگ مدل را میتوان دید
# </div>
#
# ```
# /Users/reshadhosseini/venv3.7roboflow/lib/python3.7/site-packages/ultralytics/cfg/models/v8/yolov8.yaml
# ```
#
# ```
# # Ultralytics YOLO 🚀, AGPL-3.0 license
# # YOLOv8 object detection model with P3-P5 outputs. For Usage examples see https://docs.ultralytics.com/tasks/detect
#
# # Parameters
# nc: 80  # number of classes
# scales: # model compound scaling constants, i.e. 'model=yolov8n.yaml' will call yolov8.yaml with scale 'n'
#   # [depth, width, max_channels]
#   n: [0.33, 0.25, 1024]  # YOLOv8n summary: 225 layers,  3157200 parameters,  3157184 gradients,   8.9 GFLOPs
#   s: [0.33, 0.50, 1024]  # YOLOv8s summary: 225 layers, 11166560 parameters, 11166544 gradients,  28.8 GFLOPs
#   m: [0.67, 0.75, 768]   # YOLOv8m summary: 295 layers, 25902640 parameters, 25902624 gradients,  79.3 GFLOPs
#   l: [1.00, 1.00, 512]   # YOLOv8l summary: 365 layers, 43691520 parameters, 43691504 gradients, 165.7 GFLOPs
#   x: [1.00, 1.25, 512]   # YOLOv8x summary: 365 layers, 68229648 parameters, 68229632 gradients, 258.5 GFLOPs
#
# # YOLOv8.0n backbone
# backbone:
#   # [from, repeats, module, args]
#   - [-1, 1, Conv, [64, 3, 2]]  # 0-P1/2
#   - [-1, 1, Conv, [128, 3, 2]]  # 1-P2/4
#   - [-1, 3, C2f, [128, True]]
#   - [-1, 1, Conv, [256, 3, 2]]  # 3-P3/8
#   - [-1, 6, C2f, [256, True]]
#   - [-1, 1, Conv, [512, 3, 2]]  # 5-P4/16
#   - [-1, 6, C2f, [512, True]]
#   - [-1, 1, Conv, [1024, 3, 2]]  # 7-P5/32
#   - [-1, 3, C2f, [1024, True]]
#   - [-1, 1, SPPF, [1024, 5]]  # 9
#
# # YOLOv8.0n head
# head:
#   - [-1, 1, nn.Upsample, [None, 2, 'nearest']]
#   - [[-1, 6], 1, Concat, [1]]  # cat backbone P4
#   - [-1, 3, C2f, [512]]  # 12
#
#   - [-1, 1, nn.Upsample, [None, 2, 'nearest']]
#   - [[-1, 4], 1, Concat, [1]]  # cat backbone P3
#   - [-1, 3, C2f, [256]]  # 15 (P3/8-small)
#
#   - [-1, 1, Conv, [256, 3, 2]]
#   - [[-1, 12], 1, Concat, [1]]  # cat head P4
#   - [-1, 3, C2f, [512]]  # 18 (P4/16-medium)
#
#   - [-1, 1, Conv, [512, 3, 2]]
#   - [[-1, 9], 1, Concat, [1]]  # cat head P5
#   - [-1, 3, C2f, [1024]]  # 21 (P5/32-large)
#
#   - [[15, 18, 21], 1, Detect, [nc]]  # Detect(P3, P4, P5)
# ```

# %%
from ultralytics import YOLO

model = YOLO("./yolo8.yaml")
data_location = "../notebooks-data/tyre-2"
results = model.train(data= f'../{data_location}/data.yaml', augment=True, epochs=5)
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.120 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../../notebooks-data/tyre-2/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=./yolo8.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
# WARNING no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLO8 summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 1354.5494.7 MB/s, size: 326.4 KB)
# train: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\train\labels.cache... 276 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 276/276  0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1527.8200.0 MB/s, size: 438.6 KB)
# val: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\valid\labels.cache... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      4.163      4.513      4.217         18        640: 100% ━━━━━━━━━━━━ 18/18 8.1s/it 2:264.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.7s/it 14.2s<10.3s
#                    all         78        183          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      3.628       3.68      3.798         16        640: 100% ━━━━━━━━━━━━ 18/18 7.7s/it 2:184.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8s/it 14.5s<10.3s
#                    all         78        183          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      3.096      3.228      3.307         14        640: 100% ━━━━━━━━━━━━ 18/18 7.8s/it 2:204.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s<10.4s
#                    all         78        183          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      2.855      2.867      3.007         16        640: 100% ━━━━━━━━━━━━ 18/18 7.7s/it 2:183.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s<10.4s
#                    all         78        183          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G      2.746      2.612      2.814         21        640: 100% ━━━━━━━━━━━━ 18/18 8.0s/it 2:244.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.6s<10.5s
#                    all         78        183          0          0          0          0
#
# 5 epochs completed in 0.216 hours.
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3\weights\last.pt, 6.2MB
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3\weights\best.pt, 6.2MB
#
# Validating D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3\weights\best.pt...
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO8 summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 7.8s/it 23.5s<17.7s
#                    all         78        183          0          0          0          0
# Speed: 3.2ms preprocess, 230.7ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\train-3

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین:
# </h3>
#
# - مدل یولو را از صفر ولی با استفاده از داده تایر آموزش بدهد
# - ساختار یولو را کوچکتر کنید
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# در قسمتی که پکیج نصب شده کانفیگ داده را میتوان دید
# </div>
#
# ```
# /Users/reshadhosseini/venv3.7roboflow/lib/python3.7/site-packages/ultralytics/cfg/datasets/coco.yaml
# ```
#
# ```
# # Ultralytics YOLO 🚀, AGPL-3.0 license
# # COCO 2017 dataset http://cocodataset.org by Microsoft
# # Example usage: yolo train data=coco.yaml
# # parent
# # ├── ultralytics
# # └── datasets
# #     └── coco  ← downloads here (20.1 GB)
#
#
# # Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
# path: ../datasets/coco  # dataset root dir
# train: train2017.txt  # train images (relative to 'path') 118287 images
# val: val2017.txt  # val images (relative to 'path') 5000 images
# test: test-dev2017.txt  # 20288 of 40670 images, submit to https://competitions.codalab.org/competitions/20794
#
# # Classes
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light
#   10: fire hydrant
#   11: stop sign
#   12: parking meter
#   13: bench
#   14: bird
#   15: cat
#   16: dog
#   17: horse
#   18: sheep
#   19: cow
#   20: elephant
#   21: bear
#   22: zebra
#   23: giraffe
#   24: backpack
#   25: umbrella
#   26: handbag
#   27: tie
#   28: suitcase
#   29: frisbee
#   30: skis
#   31: snowboard
#   32: sports ball
#   33: kite
#   34: baseball bat
#   35: baseball glove
#   36: skateboard
#   37: surfboard
#   38: tennis racket
#   39: bottle
#   40: wine glass
#   41: cup
#   42: fork
#   43: knife
#   44: spoon
#   45: bowl
#   46: banana
#   47: apple
#   48: sandwich
#   49: orange
#   50: broccoli
#   51: carrot
#   52: hot dog
#   53: pizza
#   54: donut
#   55: cake
#   56: chair
#   57: couch
#   58: potted plant
#   59: bed
#   60: dining table
#   61: toilet
#   62: tv
#   63: laptop
#   64: mouse
#   65: remote
#   66: keyboard
#   67: cell phone
#   68: microwave
#   69: oven
#   70: toaster
#   71: sink
#   72: refrigerator
#   73: book
#   74: clock
#   75: vase
#   76: scissors
#   77: teddy bear
#   78: hair drier
#   79: toothbrush
#
#
# # Download script/URL (optional)
# download: |
#   from ultralytics.utils.downloads import download
#   from pathlib import Path
#
#   # Download labels
#   segments = True  # segment or box labels
#   dir = Path(yaml['path'])  # dataset root dir
#   url = 'https://github.com/ultralytics/yolov5/releases/download/v1.0/'
#   urls = [url + ('coco2017labels-segments.zip' if segments else 'coco2017labels.zip')]  # labels
#   download(urls, dir=dir.parent)
#   # Download data
#   urls = ['http://images.cocodataset.org/zips/train2017.zip',  # 19G, 118k images
#           'http://images.cocodataset.org/zips/val2017.zip',  # 1G, 5k images
#           'http://images.cocodataset.org/zips/test2017.zip']  # 7G, 41k images (optional)
#   download(urls, dir=dir / 'images', threads=3)
# ```

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h2 style="text-align: right;">
# پیکربندی آموزش یولو آلترالتیکس:
#  </h2>
# </div>
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# پارامترهای پایه آموزش:
#  </h3>
# </div>
#
#
# | Argument       | Type         | Default | Description |
# |----------------|--------------|---------|-------------|
# | `model`        | `str`        | `None`  | Path to `.pt` pretrained model or `.yaml` config file. |
# | `data`         | `str`        | `None`  | Path to dataset config (e.g., `coco8.yaml`). |
# | `epochs`       | `int`        | `100`   | Total number of training epochs. |
# | `time`         | `float`      | `None`  | Max training time in hours (overrides `epochs`). |
# | `patience`     | `int`        | `100`   | Early stopping patience. |
# | `batch`        | `int/float`  | `16`    | Batch size. Use `-1` for auto (60% GPU), or fraction like `0.70`. |
# | `imgsz`        | `int/list`   | `640`   | Target image size. |
# | `device`       | `int/str/list`| `None` | Device: `0`, `[0,1]`, `cpu`, `mps`, `-1`, etc. |
# | `workers`      | `int`        | `8`     | Data loading threads. |
# | `project`      | `str`        | `None`  | Project directory name. |
# | `name`         | `str`        | `None`  | Run name (subdirectory). |
# | `exist_ok`     | `bool`       | `False` | Overwrite existing project/name. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# مدل و بهینه‌سازی:
#  </h3>
# </div>
#
#
# | Argument       | Type         | Default | Description |
# |----------------|--------------|---------|-------------|
# | `pretrained`   | `bool/str`   | `True`  | Use pretrained weights or path to model. |
# | `optimizer`    | `str`        | `'auto'`| Optimizer: `SGD`, `Adam`, `AdamW`, etc. |
# | `seed`         | `int`        | `0`     | Random seed for reproducibility. |
# | `deterministic`| `bool`       | `True`  | Enforce deterministic algorithms. |
# | `single_cls`   | `bool`       | `False` | Treat all classes as one. |
# | `classes`      | `list[int]`  | `None`  | Train only on specified class IDs. |
# | `freeze`       | `int/list`   | `None`  | Freeze first N layers or specific indices. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# جزئیات آموزش:
#  </h3>
# </div>
#
# | Argument       | Type         | Default | Description |
# |----------------|--------------|---------|-------------|
# | `rect`         | `bool`       | `False` | Rectangular training for minimal padding. |
# | `multi_scale`  | `bool`       | `False` | Multi-scale training. |
# | `cos_lr`       | `bool`       | `False` | Cosine learning rate scheduler. |
# | `close_mosaic` | `int`        | `10`    | Disable mosaic augmentation in last N epochs. |
# | `resume`       | `bool`       | `False` | Resume from last checkpoint. |
# | `amp`          | `bool`       | `True`  | Automatic Mixed Precision training. |
# | `fraction`     | `float`      | `1.0`   | Fraction of dataset to use. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# نرخ یادگیری و تابع هزینه:
#  </h3>
# </div>
#
# | Argument         | Type   | Default | Description |
# |------------------|--------|---------|-------------|
# | `lr0`            | `float`| `0.01`  | Initial learning rate. |
# | `lrf`            | `float`| `0.01`  | Final LR fraction. |
# | `momentum`       | `float`| `0.937` | Momentum for SGD / beta1 for Adam. |
# | `weight_decay`   | `float`| `0.0005`| L2 regularization. |
# | `warmup_epochs`  | `float`| `3.0`   | Warmup epochs. |
# | `warmup_momentum`| `float`| `0.8`   | Initial momentum during warmup. |
# | `warmup_bias_lr` | `float`| `0.1`   | Bias LR during warmup. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# وزنهای تابع هزینه:
#  </h3>
# </div>
#
# | Argument | Type   | Default | Description |
# |----------|--------|---------|-------------|
# | `box`    | `float`| `7.5`   | Box loss weight. |
# | `cls`    | `float`| `0.5`   | Classification loss weight. |
# | `dfl`    | `float`| `1.5`   | Distribution focal loss weight. |
# | `pose`   | `float`| `12.0`  | Pose loss weight. |
# | `kobj`   | `float`| `2.0`   | Keypoint objectness loss weight. |
# | `nbs`    | `int`  | `64`    | Nominal batch size for loss normalization. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# موارد دیگر:
#  </h3>
# </div>
#
# | Argument     | Type   | Default | Description |
# |--------------|--------|---------|-------------|
# | `cache`      | `bool` | `False` | Cache images in RAM or disk. |
# | `save`       | `bool` | `True`  | Save model checkpoints. |
# | `save_period`| `int`  | `-1`    | Save frequency in epochs. |
# | `profile`    | `bool` | `False` | Profile ONNX/TensorRT speeds. |
# | `val`        | `bool` | `True`  | Enable validation during training. |
# | `plots`      | `bool` | `False` | Save training/validation plots. |
#
#
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# میتوانید این موارد را در آموزش استفاده کنید:
#  </h3>
# </div>
#
# ```
# from ultralytics import YOLO
#
# model = YOLO('yolov8n.pt')
# model.train(data='coco128.yaml', epochs=50, imgsz=640, batch=16)
# ```

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h1 style="text-align: right;">
# ارزیابی مدل:
#  </h1>
# </div>

# %%
#!yolo task=detect mode=val model=./runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
model = YOLO("./runs/detect/yolov8/experiment-6/weights/best.pt") 
results = model.val(data= f'../{data_location}/data.yaml', project='yolov8', name='validation')

print(f"mAP (0.5-0.95): {results.box.map}")
print(f"mAP@0.5: {results.box.map50}")
# Out:
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1243.2499.8 MB/s, size: 735.8 KB)
# val: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\valid\labels.cache... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.5s/it 12.5s.8ss
#                    all         78        183      0.941      0.907      0.966      0.718
# Speed: 2.0ms preprocess, 91.9ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\validation-2
# mAP (0.5-0.95): 0.7180512000833313
# mAP@0.5: 0.9661852625107742

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین:
# </h3>
#
# - برای اینکه آموزش سریعتر شود داده ولیدیشن را برای آموزش و داده تست را برای اعتبارسنجی استفاده کنید
# -  هایپرپارامترهای مدل آلترالتیکس مانند نرخ یادگیری، مومنتم، نوع بهینه‌ساز را تغییر دهید و بهترین نتیجه را انتخاب کنید
# </div>

# %% [markdown]
# ---

# %%
from ultralytics import YOLO
import random
import math
import time
data_location = "../notebooks-data/tyre-2"
for k in range(1):
    random.seed(time.time() + k * 1000)  # Different seed each time
    params = {
    'augment': random.choice([True, False]),
    'optimizer': random.choice(['SGD', 'Adam', 'AdamW', 'RMSprop']),
    'lr0': math.pow(10, random.uniform(-4, -2)),
    'momentum': random.uniform(0.85, 0.98),
    'weight_decay': math.pow(10, random.uniform(-5, -3)),
    'warmup_epochs': random.choice([2, 3, 4, 5]),
    'close_mosaic': random.choice([0, 1, 2, 3])
    }
    model = YOLO("yolov8n.pt")
    results = model.train(data= f'../{data_location}/data_change.yaml', project = 'hyperparameters', epochs=8, **params)
    print(params)
    print(f"mAP (0.5-0.95): {results.box.map}")
    print(f"mAP@0.5: {results.box.map50}")
# Out:
# New https://pypi.org/project/ultralytics/8.4.120 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=2, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../../notebooks-data/tyre-2/data_change.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=8, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.007187650842946421, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.8533467601780451, mosaic=1.0, multi_scale=0.0, name=train-5, nbs=64, nms=False, opset=None, optimize=False, optimizer=RMSprop, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=hyperparameters, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=5.51800625786052e-05, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 1240.9294.7 MB/s, size: 575.0 KB)
# train: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\valid\labels.cache... 78 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 78/78  0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1070.4339.6 MB/s, size: 803.4 KB)
# val: Scanning D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks-data\tyre-2\train\labels.cache... 276 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 276/276  0.0s
# optimizer: RMSprop(lr=0.007187650842946421, momentum=0.8533467601780451) with parameter groups 57 weight(decay=0.0), 64 weight(decay=5.51800625786052e-05), 63 bias(decay=0.0)
# Plotting labels to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5\labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5
# Starting training for 8 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/8         0G      3.104      7.092      3.274         45        640: 100% ━━━━━━━━━━━━ 5/5 8.3s/it 41.5s<10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.0s/it 53.7s6.5ss
#                    all        276        642   3.62e-05    0.00467   2.76e-07   7.58e-08
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/8         0G      3.545      4.245      5.031         57        640: 100% ━━━━━━━━━━━━ 5/5 6.6s/it 32.8s8.4s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.5s/it 58.7s7.2ss
#                    all        276        642          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/8         0G      3.529       5.62      6.769         57        640: 100% ━━━━━━━━━━━━ 5/5 7.2s/it 36.0s8.6s5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.2s/it 56.1s6.9ss
#                    all        276        642          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/8         0G      3.346      4.862       6.62         53        640: 100% ━━━━━━━━━━━━ 5/5 6.6s/it 32.9s8.4s5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.9s/it 1:02<7.7ss
#                    all        276        642          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/8         0G      3.336       3.89       5.12         39        640: 100% ━━━━━━━━━━━━ 5/5 6.7s/it 33.3s8.5s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.1s/it 54.9s6.9ss
#                    all        276        642          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         6/8         0G      3.499      3.796       4.51         70        640: 100% ━━━━━━━━━━━━ 5/5 6.4s/it 32.2s8.2s9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 6.1s/it 55.1s6.8ss
#                    all        276        642          0          0          0          0
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         7/8         0G      3.327      3.961      4.501         33        640: 100% ━━━━━━━━━━━━ 5/5 6.5s/it 32.4s8.2s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.2s/it 46.9s5.7ss
#                    all        276        642          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         8/8         0G      3.142      3.833      4.145         33        640: 100% ━━━━━━━━━━━━ 5/5 6.5s/it 32.6s8.3s4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.2s/it 47.2s5.8ss
#                    all        276        642          0          0          0          0
#
# 8 epochs completed in 0.198 hours.
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5\weights\last.pt, 6.2MB
# Optimizer stripped from D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5\weights\best.pt, 6.2MB
#
# Validating D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5\weights\best.pt...
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.7s/it 42.2s5.0ss
#                    all        276        642          0          0          0          0
# Speed: 2.9ms preprocess, 91.3ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\hyperparameters\train-5
# {'augment': False, 'optimizer': 'RMSprop', 'lr0': 0.007187650842946421, 'momentum': 0.8533467601780451, 'weight_decay': 5.51800625786052e-05, 'warmup_epochs': 3, 'close_mosaic': 2}
# mAP (0.5-0.95): 0.0
# mAP@0.5: 0.0

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h1 style="text-align: right;">
# پیش بینی بر روی دادگان مدل:
#  </h1>
# </div>

# %%
! yolo task=detect mode=predict model=./runs/detect/train-3/weights/best.pt conf=0.015 source=../../notebooks-data/tyre-2/test/images save=True
results = model.predict(source= f'../{data_location}/test/images', project='yolov8', conf=0.02, name='predict', save=True)
# Out:
# Ultralytics 8.4.115  Python-3.12.6 torch-2.13.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO8 summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA350ZV_ext_01_jpg.rf.4a201be0617a44848b1a3f1ff0e0e01f.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA507KW_ext_05_jpg.rf.71c35ebd29c39d4f3e2adb5203574a97.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA948NP_ext_01_jpg.rf.35b6e76e76d34e53f2f865866089a0a1.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB001EK_ext_01_jpg.rf.ee4876444cf9ba2a0d87a5d0e112c8ee.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB001EK_ext_03_jpg.rf.8f5f8f7c0ae2aa81d44b2e0b259d42f5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_02_jpg.rf.83c0085f720d1dab576b3384bbec507b.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_03_jpg.rf.fecf363d64db55bb77c9899436c899c2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_07_jpg.rf.ea89b149652161fef367aac93859d1db.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AD509OQ_ext_04_jpg.rf.77d7d8ae36e01c4d7a9686e7cba997ad.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AD589LP_ext_07_jpg.rf.aa8bb990c7768346f7fff9b1c885a3ae.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AF239WA_ext_04_jpg.rf.a8a3622c9ba827cc28eb2290da1cfc20.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AF245BB_ext_06_jpg.rf.7107750ffa689d34c6aeb18281ca4daa.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AZD0I67_a9879d81_Exterior_2_jpg.rf.61e76bcec1952eace5f2d21fba269a09.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\CTI4450_ext_03_JPG.rf.cfb39d2c11919242a6b9df6bae8514ff.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\CTI4450_ext_05_JPG.rf.cca468ad028a33f597dfe8d89d4894e5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\ELO3206_ext_06_JPG.rf.9ecd8ecf25b53375635df9f005d77ff4.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\EYY9910_ext_05_JPG.rf.2b0ca931f6325238f7eb318240d0ea2a.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FDZ7871_eb36fc88_Exterior_3_jpg.rf.d7b7bbb84fb8dca34ca4acbfc1e8e494.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FED7C75_ext_08_JPG.rf.d0632e9016dced14f9597f8e7f0bc23f.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FFY9H06_1c92db93_Exterior_4_jpg.rf.89bca1610f6d6f98084381b80a7a7ea2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FHV9H05_8ba33b92_Exterior_2_jpg.rf.196125f582397550cd6f126d50d21bd5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FLN8155_c51a7723_Exterior_6_jpg.rf.17ff4ea54c3068608609ff80a9dbaba3.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FOM6899_fe8b24e8_Exterior_1_jpg.rf.5b7b8f9bd8fcce061663cc12cca2c001.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FPF2J87_ext_02_JPG.rf.95f5f8c622635d6a8eda9e0ca41b21ed.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FPF2J87_ext_03_JPG.rf.708cad056b1cdb4ec1b9c45b65f7c6ac.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FRY0858_ext_05_jpg.rf.a9dc2109847e2cf0ac17bfb4bb19e560.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FSE3338_74a355b8_Exterior_5_jpg.rf.c4e8bb4973004515af0eb5442c3c27e2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_1_jpg.rf.6c3be54902744544bbcbe23e81082f6c.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_2_jpg.rf.546e23e86131ca42382287cfc890a0bb.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_4_jpg.rf.b84cbb0c75c5d8c10262d78cf7a69337.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GBN5B09_ef93fc2f_Exterior_1_jpg.rf.4483eabc0854ae30ea1289472a7866ca.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GBN5B09_ef93fc2f_Exterior_3_jpg.rf.5bcfd6b9b82ab570e32c3601bebf2a65.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GEK5I13_ext_02_jpg.rf.9396382c0949a9c3b2b7b3406bcab063.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GIR2F59_15f287cd_Exterior_1_jpg.rf.1d64f2e34434b5b98df7d7d72ed6bd3c.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GIR2F59_15f287cd_Exterior_6_jpg.rf.bd3569e544c9e4b1d446e20b7aae1299.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\KRL478_ext_01_jpg.rf.3d7c9dd8dfcc441ecae31161c4eb5481.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\KWH283_ext_07_jpg.rf.fee94b8dff112d76c8fccba8068710f9.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\LYS211_ext_04_jpg.rf.8ff9dcd542ddd0989c48217520953cd8.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\LYS211_ext_08_jpg.rf.3394e46f40bab5a3f0dd41d01378867d.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\NKN328_ext_06_jpg.rf.d51c30e541d7c77914a02edfb1f04cc0.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\NPQ654_ext_01_jpg.rf.f44bca62e5b717c8baa5c0d1ac77b320.jpg
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\predict-4
#  Learn more at https://docs.ultralytics.com/modes/predict
#
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA350ZV_ext_01_jpg.rf.4a201be0617a44848b1a3f1ff0e0e01f.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA507KW_ext_05_jpg.rf.71c35ebd29c39d4f3e2adb5203574a97.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AA948NP_ext_01_jpg.rf.35b6e76e76d34e53f2f865866089a0a1.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB001EK_ext_01_jpg.rf.ee4876444cf9ba2a0d87a5d0e112c8ee.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB001EK_ext_03_jpg.rf.8f5f8f7c0ae2aa81d44b2e0b259d42f5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_02_jpg.rf.83c0085f720d1dab576b3384bbec507b.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_03_jpg.rf.fecf363d64db55bb77c9899436c899c2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AB659CN_ext_07_jpg.rf.ea89b149652161fef367aac93859d1db.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AD509OQ_ext_04_jpg.rf.77d7d8ae36e01c4d7a9686e7cba997ad.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AD589LP_ext_07_jpg.rf.aa8bb990c7768346f7fff9b1c885a3ae.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AF239WA_ext_04_jpg.rf.a8a3622c9ba827cc28eb2290da1cfc20.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AF245BB_ext_06_jpg.rf.7107750ffa689d34c6aeb18281ca4daa.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\AZD0I67_a9879d81_Exterior_2_jpg.rf.61e76bcec1952eace5f2d21fba269a09.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\CTI4450_ext_03_JPG.rf.cfb39d2c11919242a6b9df6bae8514ff.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\CTI4450_ext_05_JPG.rf.cca468ad028a33f597dfe8d89d4894e5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\ELO3206_ext_06_JPG.rf.9ecd8ecf25b53375635df9f005d77ff4.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\EYY9910_ext_05_JPG.rf.2b0ca931f6325238f7eb318240d0ea2a.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FDZ7871_eb36fc88_Exterior_3_jpg.rf.d7b7bbb84fb8dca34ca4acbfc1e8e494.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FED7C75_ext_08_JPG.rf.d0632e9016dced14f9597f8e7f0bc23f.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FFY9H06_1c92db93_Exterior_4_jpg.rf.89bca1610f6d6f98084381b80a7a7ea2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FHV9H05_8ba33b92_Exterior_2_jpg.rf.196125f582397550cd6f126d50d21bd5.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FLN8155_c51a7723_Exterior_6_jpg.rf.17ff4ea54c3068608609ff80a9dbaba3.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FOM6899_fe8b24e8_Exterior_1_jpg.rf.5b7b8f9bd8fcce061663cc12cca2c001.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FPF2J87_ext_02_JPG.rf.95f5f8c622635d6a8eda9e0ca41b21ed.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FPF2J87_ext_03_JPG.rf.708cad056b1cdb4ec1b9c45b65f7c6ac.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FRY0858_ext_05_jpg.rf.a9dc2109847e2cf0ac17bfb4bb19e560.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FSE3338_74a355b8_Exterior_5_jpg.rf.c4e8bb4973004515af0eb5442c3c27e2.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_1_jpg.rf.6c3be54902744544bbcbe23e81082f6c.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_2_jpg.rf.546e23e86131ca42382287cfc890a0bb.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\FTE1103_c7ea2d33_Exterior_4_jpg.rf.b84cbb0c75c5d8c10262d78cf7a69337.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GBN5B09_ef93fc2f_Exterior_1_jpg.rf.4483eabc0854ae30ea1289472a7866ca.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GBN5B09_ef93fc2f_Exterior_3_jpg.rf.5bcfd6b9b82ab570e32c3601bebf2a65.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GEK5I13_ext_02_jpg.rf.9396382c0949a9c3b2b7b3406bcab063.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GIR2F59_15f287cd_Exterior_1_jpg.rf.1d64f2e34434b5b98df7d7d72ed6bd3c.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\GIR2F59_15f287cd_Exterior_6_jpg.rf.bd3569e544c9e4b1d446e20b7aae1299.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\KRL478_ext_01_jpg.rf.3d7c9dd8dfcc441ecae31161c4eb5481.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\KWH283_ext_07_jpg.rf.fee94b8dff112d76c8fccba8068710f9.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\LYS211_ext_04_jpg.rf.8ff9dcd542ddd0989c48217520953cd8.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\LYS211_ext_08_jpg.rf.3394e46f40bab5a3f0dd41d01378867d.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\NKN328_ext_06_jpg.rf.d51c30e541d7c77914a02edfb1f04cc0.jpg
# WARNING Image Read Error d:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\..\..\notebooks-data\tyre-2\test\images\NPQ654_ext_01_jpg.rf.f44bca62e5b717c8baa5c0d1ac77b320.jpg
# Results saved to D:\00_AI_expert\Python-learning\11_hamrahe_aval_acadamy\00_workshop\06_14_Mordad\HamrahAcademy-Detection-20260805T055135Z-1-001\HamrahAcademy-Detection\notebooks\notebooks\runs\detect\yolov8\predict-4

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# مشاهده بعضی از نتایج پیش‌بینی.
# </div>

# %%
import glob
# Define the base path where the folders are located
base_path = './runs/detect/yolov8/predict'

image_paths = glob.glob(f'{base_path}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=400))
    print("\n")

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین:
# </h3>
#
# - یک تصویر از اینترنت که حاوی چندین خودرو است دانلود کنید.
# -  در یک آزمایش ابتدا به وسیله مدل پایه یولو ماشینها را دتکت کرده، ماشین را بریده و به مدل تشخیص تایر بدهید
# - در آزمایش دیگری مدل تشخیص تایر را مستقیما بر روی تصویر اعمال کنید
# - نتایج دو روش بالا را مقایسه کنید
# </div>

# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

image_path = 'image-2026-03-1.jpg'
model = YOLO("yolov8n.pt")
model_tyre = YOLO("./runs/detect/yolov8/experiment/weights/best.pt") 
img = cv2.imread(image_path)
results = model_tyre.predict(img, iou=0.3, conf=0.03, verbose=False)
for i_tyre, box_tyre in enumerate(results[0].boxes.xyxy):
    x1_t, y1_t, x2_t, y2_t = map(int, box_tyre)
    cv2.rectangle(img, (x1_t, y1_t), (x2_t, y2_t), (255, 0, 0), 2)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off') # Hide axes
plt.title('Tyre detector')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h1 style="text-align: right;">
# اکسپورت کردن و دیپلوی کردن مدل:
#  </h1>
# در اینجا برای فرمت
# onnx
# توضیح داده میشود.
# </div>

# %%
# pip install onnxruntime

from ultralytics import YOLO

# Load the YOLO model
model = YOLO("./runs/detect/yolov8/experiment/weights/best.pt") 

# Export the model to ONNX format
model.export(format="onnx")
# Out:
# Ultralytics 8.4.115 🚀 Python-3.9.6 torch-2.2.2 CPU (Intel Core i5-5257U 2.70GHz)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs/detect/yolov8/experiment/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.9 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 17...
# ONNX: slimming with onnxslim 0.1.95...
# ONNX: export success ✅ 2.5s, saved as 'runs/detect/yolov8/experiment/weights/best.onnx' (11.7 MB)
#
# Export complete (3.0s)
# Results saved to /Users/reshadhosseini/Downloads/HamrahAcademy/notebooks/runs/detect/yolov8/experiment/weights/best.onnx
# Predict:         yolo predict task=detect model=runs/detect/yolov8/experiment/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/yolov8/experiment/weights/best.onnx imgsz=640 data=/Users/reshadhosseini/Downloads/HamrahAcademy/notebooks/tyre-2/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/yolov8/experiment/weights/best.onnx'

# %%
import onnxruntime as rt
import numpy as np
import glob

# Load the ONNX model
session = rt.InferenceSession("./runs/detect/yolov8/experiment/weights/best.onnx")

# Get input and output names
input_name = session.get_inputs()[0].name
output_names = [output.name for output in session.get_outputs()]

# Define the target input size for the ONNX model
input_size = (640, 640)

# Define the base path where the folders are located
base_path = '../notebooks-data/tyre-2/test/images'

image_path = glob.glob(f'{base_path}/*.jpg')[5]
image = cv2.imread(image_path)

# Resize the image while maintaining aspect ratio and padding
# This is a common method to prepare images for YOLO models
h, w = image.shape[:2]
scale = min(input_size[0] / h, input_size[1] / w)
resized_h, resized_w = int(h * scale), int(w * scale)
resized_image = cv2.resize(image, (resized_w, resized_h), interpolation=cv2.INTER_AREA)

padded_image = np.full((input_size[0], input_size[1], 3), 114, dtype=np.uint8) # Pad with a neutral color (e.g., gray)
x_offset = (input_size[1] - resized_w) // 2
y_offset = (input_size[0] - resized_h) // 2
padded_image[y_offset:y_offset + resized_h, x_offset:x_offset + resized_w] = resized_image

# Convert BGR to RGB (if your model expects RGB)
rgb_image = cv2.cvtColor(padded_image, cv2.COLOR_BGR2RGB)

# Normalize pixel values to 0-1 range
normalized_image = rgb_image.astype(np.float32) / 255.0

# Transpose to CHW (Channels First) and add batch dimension
# Assuming the ONNX model expects (1, 3, 640, 640)
input_tensor = np.transpose(normalized_image, (2, 0, 1)) # HWC to CHW
input_tensor = np.expand_dims(input_tensor, axis=0) # Add batch dimension

outputs = np.array(session.run(None, {input_name: input_tensor})[0])[0]
print(outputs.shape)
print(outputs[:,500])
# Out:
# (5, 8400)
# [     173.34       46.75      109.01      64.374  0.00057161]

# %% [markdown]
# .........<div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین:
# </h3>
#
# - شکل کانفیدنسها را رسم کنید
# - با استفاده از تابع بخش پنجره لغزان که نقاط غیر ماکزیمم را حذف میکرد باندینگ باکس را بر روی شکل رسم کنید
# </div>

# %%
output_confidence = outputs[4,0:6400].reshape(80, 80)
plt.imshow(output_confidence, cmap='coolwarm', interpolation='nearest')
plt.axis('off') 
plt.show()

output_confidence = outputs[4,6400:6400+1600].reshape(40, 40)
plt.imshow(output_confidence, cmap='coolwarm', interpolation='nearest')
plt.axis('off') 
plt.show()

img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off') 
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین برای هفته بعد:
# </h3>
#
# - داده‌های چهره قسمت مربوط به پنجره لغزان را به فرمت یولو تبدیل کنید
# - مدل یولو را برای تشخیص صورت بر روی این دادگان اعمال کنید و نتایج را گزارش دهید
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# <h3 style="text-align: right;">
# تمرین برای هفته بعد:
# </h3>
#
# - بر روی تصاویری تایر مدل تشخیص خودرو را اعمال کنید
# - با استفاده از نتیجه مدل داده‌ای را ایجاد کنید که هم کلاس خودرو داشته باشد و هم کلاس تایر
# - مدل جدیدی را بر روی این پایگاه داده آموزش دهید و نتیجه را گزارش دهید
# </div>
