# %% [markdown]
# ##Read Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('/content/Cars.jpg')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
plt.imshow(image)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
bus = image_gray[300:370, 1050:1150] 
plt.imshow(bus,cmap="gray")
plt.title('bus')
# Out:
# Text(0.5, 1.0, 'bus')

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
p206 = image_gray[590:680, 190:310] 
plt.imshow(p206,cmap="gray")
plt.title('p206')
# Out:
# Text(0.5, 1.0, 'p206')

# %% [markdown]
# **Template Matching**
#
# ##Complete this section

# %%
def template_matching(source, template):
    #...
    #...
    #Output is Up-left corner coordinate
    return(pt[1], pt[0])

# %% [markdown]
# Show the found matches on Cars image.

# %%
fig = plt.figure(figsize=(18, 10))
ax1 = plt.subplot(2, 2, 1)
ax2 = plt.subplot(2, 2, 2)
ax3 = plt.subplot(2, 2, 3)
ax4 = plt.subplot(2, 2, 4)

# plot p206
h_small, w_small = p206.shape

xs, ys = template_matching(image_gray, p206)

ax1.imshow(p206, cmap=plt.cm.gray)
ax1.set_title('p206')
# plot p206 on Image
ax2.imshow(image, cmap=plt.cm.gray)
ax2.set_title('p206 on Highway')
rect = plt.Rectangle((xs, ys), w_small, h_small, edgecolor='r', facecolor='none')
ax2.add_patch(rect)

#######################################################################################

# plot Bus
h_large, w_large = bus.shape

xl, yl = template_matching(image_gray, bus)

ax3.imshow(bus, cmap=plt.cm.gray)
ax3.set_title('bus')
# plot Bus on Image
ax4.imshow(image, cmap=plt.cm.gray)
ax4.set_title('bus on Highway')
rect = plt.Rectangle((xl, yl), w_large, h_large, edgecolor='r', facecolor='none')
ax4.add_patch(rect)
