# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img1 = cv2.imread('/content/img1.jpg',0)
img2 = cv2.imread('/content/img2.jpg',0)
img3 = cv2.imread('/content/img3.jpg',0)
img4 = cv2.imread('/content/img4.jpg',0)

def draw(img1,img2,img3,img4,title=['img1','img2','img3','img4']):
  fig = plt.figure(figsize=(18, 10));
  ax1 = plt.subplot(2, 2, 1);ax2 = plt.subplot(2, 2, 2)
  ax3 = plt.subplot(2, 2, 3);ax4 = plt.subplot(2, 2, 4)

  ax1.imshow(img1, cmap=plt.cm.gray);ax1.set_title(title[0]);ax2.imshow(img2, cmap=plt.cm.gray);ax2.set_title(title[1])
  ax3.imshow(img3, cmap=plt.cm.gray);ax3.set_title(title[2]);ax4.imshow(img4, cmap=plt.cm.gray);ax4.set_title(title[3])

draw(img1,img2,img3,img4)

# %% [markdown]
# ##Write function Sobel, Prewitt, Canny, LoG (Complete this section)

# %%
def Sobel(img):
  #...

def Prewitt(img):
  #...

def Canny(img,tr1,tr2):
  #...

def LoG(img):
  #...

# %% [markdown]
# ##img1

# %%
draw(Sobel(img1),Prewitt(img1),Canny(img1,100,200),LoG(img1),title=['Sobel','Prewitt','Canny','LoG'])

# %% [markdown]
# #img2

# %%
draw(Sobel(img2),Prewitt(img2),Canny(img2,100,200),LoG(img2),title=['Sobel','Prewitt','Canny','LoG'])

# %% [markdown]
# #img3

# %%
draw(Sobel(img3),Prewitt(img3),Canny(img3,100,200),LoG(img3),title=['Sobel','Prewitt','Canny','LoG'])

# %% [markdown]
# #img4

# %%
draw(Sobel(img4),Prewitt(img4),Canny(img4,100,200),LoG(img4),title=['Sobel','Prewitt','Canny','LoG'])
