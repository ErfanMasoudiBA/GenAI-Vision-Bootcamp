# %% [markdown]
# #Read Image

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img1 = cv.imread('/content/Samand.jpg')
img2 = cv.imread('/content/Cars.jpg')

plt.imshow(cv.cvtColor(img1, cv.COLOR_RGB2BGR));plt.figure();plt.imshow(cv.cvtColor(img2, cv.COLOR_RGB2BGR));

# %% [markdown]
# ##Keypoint Detection and Description (Complete this section)

# %%
def sift(img1,img2,tr): 
  #tr is threshold for matching
  # Initiate SIFT detectorn
  sift = cv.SIFT_create()
  # find the keypoints and descriptors with SIFT
  #...
  
  #...
  return keypoint_matched

# %% [markdown]
# ##Show Samand 1 (Complete this section)

# %%
img1_gray = cv.cvtColor(img1, cv.COLOR_RGB2GRAY)
img2_gray = cv.cvtColor(img2, cv.COLOR_RGB2GRAY)
#keypoint_matched = sift(img1_gray,img2_gray,...)
#...
#...
#plt.imshow(cv.cvtColor(samand1, cv.COLOR_RGB2BGR));

# %% [markdown]
# ##Show Samand 2 (Complete this section)

# %%
#Delete samand 1
#...
#...
plt.imshow(new_image,cmap='gray')

# %% [markdown]
# ##Show Samand 2 (Complete this section)

# %%
#keypoint_matched = sift(img1,new_image,...)
#...
#...
#plt.imshow(cv.cvtColor(samand2, cv.COLOR_RGB2BGR));
