# %% [markdown]
# #Find and draw key points
# you can use:
#
#   orb = cv2.ORB_create()
#
#   orb.detectAndCompute()
#
#   cv2.drawKeypoints()

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# Load the images


# Detect keypoints and descriptors


# Draw the keypoints on the image


# Show the image with keypoints using Matplotlib

# %% [markdown]
# #Find and draw matches
#
# you can use:
#
# cv2.BFMatcher()
#
# cv2.drawMatches()

# %%
# Match keypoints using brute-force matcher

# Sort matches by distance


# Draw top 10 matches on image

# Show the image with matches using Matplotlib

# %% [markdown]
# #Find Homography matrix with RANSAC
#
# you can use:
#
# cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 0.2)

# %%
# Estimate homography using RANSAC

# %% [markdown]
# # Apply Homography matrix
#
# you can use:
#
# warped_img = cv2.warpPerspective()
