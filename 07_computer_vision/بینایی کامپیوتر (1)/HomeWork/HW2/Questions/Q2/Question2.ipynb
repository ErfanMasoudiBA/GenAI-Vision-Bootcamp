# %% [markdown]
# # تمرین اول درس بینایی کامپیوتر
# در این سوال قصد داریم داریم با محاسبه ماتریس هموگرافی بین دو تصویر، تصویر تبلیغ مورد نظر و تصویر مربوط به بیلبورد، تناظر بین نقاط دو تصویر را بدست بیاوریم و سپس با استفاده از ماتریس هموگرافی محاسبه شده تبلیغ مورد نظر را روی بیلبورد نگاشت کنیم
#
#  کتابخانه‌های لازم برای کار خود را در زیر اضافه کنید

# %%
# تمامی پکیج هایی که لازم دارید را در زیر اضافه کنید
import numpy as np
import cv2
import imageio

# %% [markdown]
# ### گام اول
# ابتدا دو تصویر مربوط به بیلبورد و تبلیغ را در ورودی بخوانید و لود کنید و آنها را نمایش دهید

# %%
# با دستور زیر دو تصویر مورد نظر را بخوانید. برای این کار آدرس کامل دو تصویر را وارد کنید
bilboard = cv2.imread('')
ad = cv2.imread('')

# تصاویر خوانده شده را با دستور مناسب نمایش دهید

# %% [markdown]
# ### گام دوم
# حال 4 جفت نقطه متناظر بین دو تصویر را محاسبه کنید و با استفاده از کتابخانه $OpenCV$ ماتریس هموگرافی را محاسبه کرده و نمایش دهید

# %%
# حال 4 جفت نقطه متناظر را مشخص میکنیم 
points_bil = np.array([[98, 270], [288, 1132], [404, 240],[525, 1152]])   # مختصات چهار گوشه بیلبورد به ترتیب: بالاچپ، بالا راست، پایین چپ و پایین راست
points_ad = np.array([[?, ?], [?, ?], [?, ?],[?, ?]]) # به جای علامت های سوال به همان ترتیب بالا، مختصات چهار گوشه مربوط به تصویر تبلیغ را وارد کنید


# سپس با استفاده از کتابخانه مناسب ماتریس هموگرافی بین دو تصویر را محاسبه و نمایش دهید

# %% [markdown]
# ### گام سوم
# در نهایت با داشتن ماتریس هموگرافی بین دو تصویر، تمامی نقاط تصویر تبلیغ را بر روی تصویر بیلبورد نگاشت کنید. در نهایت تصویر تبلیغ نگاشت شده روی بیلبورد را نمایش دهید

# %%
# تصویر تبلیغ را با استفاده از دو حقله تکرار و ماتریس هموگرافی بر روی تصویر بیلبورد نگاشت کنید

# %% [markdown]
# ### تمرین بیشتر
# برای تمرین بیشتر و گرفتن نمره امتیازی این بار یگ گیف را از ورودی بخوانید و همین کار را این بار برای فریم‌‌های مختلف گیف انجام دهید و هر فریم آن را مانند یک تصویر تبلیغ در نظر بگیرید و آن را روی بیلبورد نگاشت کنید. در نهایت گیف جدید را بازسازی  و ذخیره کنید

# %%
# برای خواندن گیف از دستور زیر استفاده کنید
gif = cv2.VideoCapture('')

# همان کارهای قسمت قبل را اینبار برای تمامی فریم های گیف انجام دهید









# در نهایت گیف نهایی را ذخیره کنید. برای این کار از کتابخانه مناسب استفاده کنید
# imageio -> getwriter
