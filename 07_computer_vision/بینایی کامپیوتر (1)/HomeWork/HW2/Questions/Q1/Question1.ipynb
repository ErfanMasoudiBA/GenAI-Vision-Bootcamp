# %% [markdown]
# #تمرین اول درس بینایی کامپیوتر
# در این تمرین قصد داریم با داشتن ماتریس هموگرافی$H$، آن را تجزیه کرده و در نهایت ماتریس‌های $R$ و بردار انتقال $T$ را محاسبه کنیم
#
# کتابخانه‌های لازم برای کار خود را در زیر اضافه کنید

# %%
import numpy as np

# %% [markdown]
# ### گاوم اول
#
# ابتدا نیاز داریم که ماتریس را نرمال کنیم. برای این کار ابتدا [تجزیه مقادیر ویژه](https://en.wikipedia.org/wiki/Singular_value_decomposition) ماتریس را انجام داده و با بدست آوردن مقادیر ویژه ماتریس مورد نظر، مقادیر ماتریس را بر دومین مقدار ویژه بزرگ ماتریس تقسیم میکنیم

# %%
# ماتریس مورد نظر خود را در پایین وارد کنید
H = np.matrix([[0, 0, 0], 
               [0, 0, 0], 
               [0, 0, 0]])

# تجزیه مقادیر ویژه ماتریس بالا انجام شود و با تقسیم کردن آن بر دومین مقدار ویژه بزرگ آن، نرمال سازی را انجام دهی

# %% [markdown]
# ### گام دوم
# حال با تشکیل ماتریس $H^TH$ و محاسبه بردارها و مقادیر ویژه آن، ماتریس‌های $u$و $w$ را طبق فرمول‌های زیر محاسبه کنید. اطلاعات بیشتر درمورد عملگر $hat(\wedge)$ را از [اینجا](https://en.wikipedia.org/wiki/Hat_operator) بخوانید
# ![1.png](data:image/png;base64,...)

# %%
# ابتدا ماتریس مورد نظر را تعریف کنید
# H_new = H^T H


# طبق فرمول های بالا، ماتریس های گفته شده را محاسبه کرده و نمایش دهید

# %% [markdown]
# ### گام سوم
# در این مرحله تمامی مقادیر ممکن برای ماتریس $R$، بردار $T$ و بردار نرمال $N$ را محاسبه میکنیم. برای محاسبه چهار مقدار مختلف، از فرمول‌های زیر استفاده کنید
# ![1.png](data:image/png;base64,...)

# %%
# تمامی 4 مقدار بالا را طبق فرمول‌ها محاسبه کنید

# %% [markdown]
# ### سوال مربوط به تمرین
# در این تمرین با داشتن ماتریس هوموگرافی و با استفاده از تجریه مقادیر ویژه توانستیم پارامترهای داخلی دوربین را بازیابی کنیم. در نهایت برای این پارامتر‌ها 4 مقدار مختلف بدست آمد. تعبیر شما از این مقادیر مختلف چیست؟ کدام یک جواب درست مسئله است؟ جواب خود در همین سلول بنویسید
#
# جواب:
