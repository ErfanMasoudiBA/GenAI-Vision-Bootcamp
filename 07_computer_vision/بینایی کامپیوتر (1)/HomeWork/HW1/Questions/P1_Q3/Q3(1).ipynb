# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# load image


# convert to gray scale image

# Apply Laplacian filtering and normalization



# Show the output image using matplotlib.pyplot
