# %%
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# read  image and depth by o3d.io.read_image()
# create a RGBD image


# create RGBD image with o3d.geometry.RGBDImage.create_from_color_and_depth()
# Out:
# RGBDImage of size
# Color image : 640x480, with 3 channels.
# Depth image : 640x480, with 1 channels.
# Use numpy.asarray to access buffer data.

# %%
#show image and depth from RGBD object( RGBD_obj.color and RGBD_obj.depth)

# %%
# read trajectory.log by o3d.io.read_pinhole_camera_trajectory()
# see this for more information http://redwood-data.org/indoor/fileformat.html

# %%
#print extrinsic parameters of first frame in trajectory object
# Out:
# array([[-2.73959219e-01,  8.67361738e-19, -9.61741310e-01,
#          1.96003743e+00],
#        [ 2.18193459e-02, -9.99742609e-01, -6.21540418e-03,
#          5.92858340e-01],
#        [-9.61493766e-01, -2.26873336e-02,  2.73888704e-01,
#         -8.68039442e-01],
#        [ 0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          1.00000000e+00]])

# %%
#print intrinsic parameters of first frame
# Out:
# array([[525. ,   0. , 319.5],
#        [  0. , 525. , 239.5],
#        [  0. ,   0. ,   1. ]])

# %%
# create a point cloud from RGBD image and parameters of camera and visualize it
