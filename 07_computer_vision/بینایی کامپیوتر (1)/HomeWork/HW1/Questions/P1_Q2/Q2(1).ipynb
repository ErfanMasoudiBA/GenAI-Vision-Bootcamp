# %% [markdown]
# ##compute Fourier transform of image3 and apply different filtering on it and then use inverse DFT to compute the source image

# %% [markdown]
# ### Fourier transform

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np


# load the image

#Output is a 2D complex array. 1st channel real and 2nd imaginary


#Rearranges a Fourier transform X by shifting the zero-frequency 


##Magnitude of the function is 20.log(abs(f))

# %% [markdown]
# ### low-pass filter

# %%
# Circular LPF mask, center circle is 1, remaining all zeros



# apply mask and inverse DFT



#plot result
# Out:
# <ipython-input-19-d8f12e36fb0d>:17: RuntimeWarning: divide by zero encountered in log
#   fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:, :, 0], fshift[:, :, 1]))

# %% [markdown]
# ## high-pass filter

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# Circular HPF mask, center circle is 0, remaining all ones


# apply mask and inverse DFT


#plot result
# Out:
# <ipython-input-20-f3cc4fdf04ba>:21: RuntimeWarning: divide by zero encountered in log
#   fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:, :, 0], fshift[:, :, 1]))

# %% [markdown]
# ###Band-pass filter

# %%
# Band Pass Filter - Concentric circle mask, only the points living in concentric circle are ones


# apply mask and inverse DFT


#plot result
# Out:
# <ipython-input-21-c5d3cc4beaac>:15: RuntimeWarning: divide by zero encountered in log
#   fshift_mask_mag = 2000 * np.log(cv2.magnitude(fshift[:, :, 0], fshift[:, :, 1]))
