# %% [markdown]
# in this section you should first install open3d after that you should visualize the point cloud has given to you.
# the given point cloud is in the room.txt file. The first 3 columns are XYZ and the last 3 columns are RGB of each point.

# %%
import numpy as np
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# read point cloud file by np.loadtxt

# %%
# convert data to point cloud
# create a point_cloud class with o3d.geometry.PointCloud()
# this class has two values pcd.points and pcd.colors assign values to them
# see this: http://www.open3d.org/docs/release/python_api/open3d.utility.Vector3dVector.html
# note : you should normalize the RGB values to [0-1] current scale is [0-255]

# %%
# draw point cloud with o3d.visualization.draw_geometries([])
# see this:http://www.open3d.org/docs/release/python_example/geometry/point_cloud/index.html
# use mouse for zoom in
