# %% [markdown]
# # import or clone a code one recommendation is :
# https://github.com/sniklaus/pytorch-hed.git

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/sniklaus/pytorch-hed.git
# Out:
# Cloning into 'pytorch-hed'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 106 (delta 0), reused 1 (delta 0), pack-reused 103
# Receiving objects: 100% (106/106), 53.00 MiB | 28.42 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# Open the image file


# Resize the image to (480, 320)


# Save the resized image

# %%
cd /content/pytorch-hed
# Out:
# /content/pytorch-hed

# %%
# run code on image3

# %%
#plot result
