# %% [markdown]
# calculate Fourier transform of image1 and image2

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# for image1

# %%
# load image by cv2.imread("Path" , 0)

# use cv2.dft for computing real and imaginary parts of the image1 and print each part

# use np.fft.fftshift to move low frequnceies to center

# use cv2.magnitude to compute the magnitude of the Fourier transform 


# plot image

# %% [markdown]
# for image2

# %%
# load image by cv2.imread("Path" , 0)

# use cv2.dft for computing real and imaginary parts of the image1 and print each part

# use np.fft.fftshift to move low frequnceies to center

# use cv2.magnitude to compute the magnitude of the Fourier transform 


# plot image

# %% [markdown]
# why the Fourier transform in the second image is expanded compared to the first image?

# %%
# comment you answer to question
#
#
#
#
#
